# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### read the scraped data using pandas

# %%
raw_data = pd.read_csv("raw_data.csv")

# %%
raw_data.head(2)
# Out:
#                                       Title              Company  \
# 0                    AR/VR Business Analyst  Tailored Management
# 1  Producer, Augmented Reality (Menlo Park)      The Mom Project
#
#          Location                                                 JD  \
# 0  Menlo Park, CA  skills:  Consolidate third-party retailer sale...
# 1  Menlo Park, CA  skills:  Work closely with creative leads to s...
#
#                                                  URL
# 0  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
# 1  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...

# %% [markdown]
# ### perform basic cleaning on JD

# %%
# remove any special characters and remove new line \n
raw_data['JD'] = raw_data["JD"].map(lambda x: re.sub('[,\.!?]', '', x))
raw_data['JD'] = raw_data['JD'].map(lambda x: x.replace("\n",""))

# %%
# generate new feature by converting the cleaned data into lower case
raw_data['JD_processed'] = raw_data['JD'].map(lambda x: x.lower())

# %%
raw_data.head(2)
# Out:
#                                       Title              Company  \
# 0                    AR/VR Business Analyst  Tailored Management
# 1  Producer, Augmented Reality (Menlo Park)      The Mom Project
#
#          Location                                                 JD  \
# 0  Menlo Park, CA  skills:  Consolidate third-party retailer sale...
# 1  Menlo Park, CA  skills:  Work closely with creative leads to s...
#
#                                                  URL  \
# 0  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
# 1  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
#
#                                         JD_processed
# 0  skills:  consolidate third-party retailer sale...
# 1  skills:  work closely with creative leads to s...

# %% [markdown]
# ### A function to assign Job roles based on the job title

# %%
def assign_roles(row):
    row = row.lower()
    if 'accountant' in row:
        return 'accountant'
    elif 'marketing' in row:
        return 'marketing'
    elif 'security' in row and 'manager' in row:
        return 'security'
    elif 'manager' in row and 'engineer' in row:
        return 'Engineering manager'
    elif 'manager' in row:
        return 'manager'
    elif 'director' in row:
        return 'director'
    elif 'software' in row or 'engineer' in row:
        return 'engineer'
    elif 'finance' in row:
        return 'financial analyst'
    elif 'analyst' in row:
        return 'analyst'
    else:
        return 'other'

# %%
# add job role feature to the dataset 
# categorize job listing
raw_data['Role'] = raw_data['Title'].apply(lambda row: assign_roles(row))
raw_data.head()
# Out:
#                                                Title  \
# 0                             AR/VR Business Analyst
# 1           Producer, Augmented Reality (Menlo Park)
# 2           Content Manager, AR/VR (Japanese Market)
# 3                       AR/VR Apps Review Specialist
# 4  Strategic Planning & Operations Lead for Faceb...
#
#                     Company        Location  \
# 0       Tailored Management  Menlo Park, CA
# 1           The Mom Project  Menlo Park, CA
# 2  An Innovative VR Company  Menlo Park, CA
# 3                  Facebook  Menlo Park, CA
# 4                  Facebook  Menlo Park, CA
#
#                                                   JD  \
# 0  skills:  Consolidate third-party retailer sale...
# 1  skills:  Work closely with creative leads to s...
# 2  skills:  Curate and manage the App Store and a...
# 3  skills:  Execute testing process for third par...
# 4  skills:  Strategic Planning: Collaborate with ...
#
#                                                  URL  \
# 0  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
# 1  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
# 2  https://www.indeed.com//pagead/clk?mo=r&ad=-6N...
# 3  https://www.indeed.com//rc/clk?jk=11bf7d641f87...
# 4  https://www.indeed.com//rc/clk?jk=4edd3fa153d3...
#
#                                         JD_processed     Role
# 0  skills:  consolidate third-party retailer sale...  analyst
# 1  skills:  work closely with creative leads to s...    other
# 2  skills:  curate and manage the app store and a...  manager
# 3  skills:  execute testing process for third par...    other
# 4  skills:  strategic planning: collaborate with ...    other

# %%
# check how many job rols in each category we have
raw_data.Role.value_counts()
# Out:
# manager                17
# other                  17
# engineer               15
# marketing              11
# analyst                 9
# director                7
# Engineering manager     2
# accountant              1
# financial analyst       1
# Name: Role, dtype: int64

# %% [markdown]
# ### Job Description Column cleaning

# %%
# stop words to remove from the JD that doen't add any meaning to the JD Skills
from stop_words import get_stop_words
en_stop = get_stop_words('en')
en_stop.extend(['work','monday','friday','day','shift','hour','authorization''globally', 'approvals', 'keep', 'revision', 'months',
       'roadblocks', 'child', 'expression', 'facilitates', 'birth','spec', 'spouse', 'stakeholder','desired', 'advising', 'proposed', 'align', 'alike', 'daily',
       'medical', 'meets', 'days', 'effects', 'mr', 'anchor', 'predict','benefit', 'implemented', 'benefits', 'delivered','years','experience',
       'ltd', 'deployment', 'assignment', 'unlock','401k', '4000','articulating', 'pto', 'schedules', 'conditions', 'life',
       'agencies', 'std','united','states'])

# %% [markdown]
# ### NLP Using RAKE
# ***
# RAKE short for Rapid Automatic Keyword Extraction algorithm, is a domain independent keyword extraction algorithm which tries to <br> determine key phrases in a body of text by analyzing the frequency of word appearance and its co-occurance with other words in the text.

# %%
# a function to convert the list of words into a string for 
# drawing a word cloud later for different job roles
def get_words_as_string(words):
    text = ""
    for item in words:
        print(item[1])
        text +=" " + item[1]
    return text

# %%
# a function to draw word cloud for different types of jobs
# save the output to local file system
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def draw_word_cloud(text,fname,st_wrds):
    fname="images/"+fname+".png"
    wordcloud = WordCloud(stopwords=st_wrds,max_font_size=60).generate(text)
    wordcloud.to_file(filename=fname)
    plt.figure(figsize=(16,12))

    # plot wordcloud in matplotlib
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### AR/VR Analyst Job posting

# %%
# import rake library
from rake_nltk import Rake
# Uses stopwords for english from NLTK, and all puntuation characters.
r = Rake(
    stopwords=en_stop,
    max_length=3,
    min_length=1,)

# %%
# extract the keywords (skill sets) from the JD of the job posts 
# for the position of AR/VR analyst in Menlo Park, CA.
r.extract_keywords_from_text(''.join(raw_data[raw_data["Role"]=="analyst"].JD_processed.values))
skills = r.get_ranked_phrases_with_scores()

# %%
# filter out the less important words from the result
# based on the scores of each words assigned by RAKE NLTK Library
skills_analyst = list(filter(lambda x: float(x[0]) >= 4.5 , skills))

# %% [markdown]
# ### varify the top 5 skill sets required for a Analyst job in AR/VR domain

# %%
skills_analyst[0:5]
# Out:
# [(9.0, 'similar scripting language'),
#  (9.0, 'retail industry preferred'),
#  (9.0, 'presto spark hive'),
#  (9.0, 'nps csat etc'),
#  (9.0, 'manipulating raw datasets')]

# %%
# create string from the list of tuples for drawing wordcloud
text = get_words_as_string(skills_analyst)
# Out:
# similar scripting language
# retail industry preferred
# presto spark hive
# nps csat etc
# manipulating raw datasets
# maintain robust pipelines
# influence decision making
# gather business requirements
# eg nps csat
# distribution strategies design
# continuously developing periodic
# bi tools ability
# similar quantitative fields
# driven tools reports
# creating reports visualizations
# consumer electronics environment
# analysis using sql
# customer feedback proficiency
# customer feedback across
# reporting using tableau
# data etl preferred
# dashboards using tableau
# sales analytics reporting
# quantitative research projects
# analysis sql skills
# ad hoc reports
# technical audiences bs
# support sales leadership
# presenting insights partner
# consumer insights
# using r
# statistical analysis
# quantitative discipline
# upload reports
# technical audiences

# %% [markdown]
# ## EDA
# ***
# Let's draw a wordcloud using the extracted keywords from the JD for an Analyst role

# %%
# remove some noises from the output
st_wrds = ['using','similar','feedback','reports','preferred','consumer','customer','etc','audiences']

# %%
draw_word_cloud(text,"analyst",st_wrds)

# %% [markdown]
# ### AR/VR Developer/Engineer Job posting

# %%
# extract the keywords (skill sets) from the JD of the job posts 
# for the position of AR/VR engineer in Menlo Park, CA.
r.extract_keywords_from_text(''.join(raw_data[raw_data["Role"]=="engineer"].JD_processed.values))

skills_engineer = r.get_ranked_phrases_with_scores()

# %%
# filter out the less important words from the result
# based on the scores of each words assigned by RAKE NLTK Library
skills_engineer = list(filter(lambda x: int(x[0]) > 3 , skills_engineer))

# %%
skills_engineer[:10]
# Out:
# [(9.0, 'visual system guide'),
#  (9.0, 'underlying implementations used'),
#  (9.0, 'translation lookaside buffer'),
#  (9.0, 'status escalating risks'),
#  (9.0, 'ray tracing rasterization'),
#  (9.0, 'printed circuit board'),
#  (9.0, 'modifying camera pipeline'),
#  (9.0, 'injection molding die'),
#  (9.0, 'highlight missing functionality'),
#  (9.0, 'fea structural simulations')]

# %%
skills_engineer[-10:-5]
# Out:
# [(4.0, 'debug guides'),
#  (4.0, 'computer science'),
#  (4.0, 'complete current'),
#  (4.0, 'business goals'),
#  (4.0, 'box user')]

# %%
len(skills_engineer)
# Out:
# 337

# %%
# create string from the list of tuples for drawing wordcloud
# lets take first 50 words only 
text = get_words_as_string(skills_engineer[:50])
# Out:
# visual system guide
# underlying implementations used
# translation lookaside buffer
# status escalating risks
# ray tracing rasterization
# printed circuit board
# modifying camera pipeline
# injection molding die
# highlight missing functionality
# fea structural simulations
# delivering aaa games
# assemble bench setups
# 6s spc cpk
# volume production stages
# production phase experienced
# wifi logo testing
# final acceptance testing
# minimal supervision knowledge
# volume manufacturing experienced
# pc usb bluetooth
# eg electrical organizational
# 2d cad masters
# qa strategy development
# feature development bring
# executing development projects
# ready test stations
# managing test coverages
# improving test efficiency
# improve test strategies
# projects apply engineering
# engineering engagement models
# new device bring
# video conferencing technologies
# technical tasks experienced
# c ++ familiarity
# using various sdks
# cost effectiveness 3
# vendor sites troubleshoot
# shipping reliable products
# led displays knowledge
# packaging software testing
# automated tests partner
# bringing new technologies
# testing vision systems
# device driver development
# version control software
# c swift c
# deploy advanced manufacturing
# c swift etc
# developing oculus products

# %% [markdown]
# ## EDA
# ***
# Let's draw a wordcloud using the extracted keywords from the JD for an Engineer role

# %%
st_wrds = ['product','manufacturing','knowledge','electronics','quality','mechanical','shipping']

# %%
draw_word_cloud(text,"engineer",st_wrds)

# %% [markdown]
# ### AR/VR Engineering manager Job posting

# %%
# extract the keywords (skill sets) from the JD of the job posts 
# for the position of AR/VR manager in engineering in Menlo Park, CA.
r.extract_keywords_from_text(''.join(raw_data[raw_data["Role"]=="Engineering manager"].JD_processed.values))

skills_engineer_manager = r.get_ranked_phrases_with_scores()

# %%
# filter out the less important words from the result
# based on the scores of each words assigned by RAKE NLTK Library
skills_engineer_manager = list(filter(lambda x: int(x[0]) > 4 , skills_engineer_manager))

# %%
skills_engineer_manager[:5]
# Out:
# [(9.0, 'windows linux mac'),
#  (9.0, 'skill levels long'),
#  (9.0, 'operations establishing metrics'),
#  (9.0, 'dedicated recruiting staff'),
#  (9.0, 'continued development 10')]

# %%
# create string from the list of tuples for drawing wordcloud
text = get_words_as_string(skills_engineer_manager)
# Out:
# windows linux mac
# skill levels long
# operations establishing metrics
# dedicated recruiting staff
# continued development 10
# consumer electronics devices
# performance management 7
# supporting coaching mentoring
# product offerings leverage
# developer infrastructure strategy
# constrained environment yet
# industry champion engineering
# management teams 3
# toolchain projects across
# solid project framework
# c ++/ java
# launching software products
# developing engineers demonstrated
# managing engineering teams
# lead team designing
# management teams

# %% [markdown]
# ## EDA
# ***
# Let's draw a wordcloud using the extracted keywords from the JD for an Engineer Manager role

# %%
draw_word_cloud(text,"Engineering Manager",[])

# %% [markdown]
# ### AR/VR financial analyst Job posting

# %%
# extract the keywords (skill sets) from the JD of the job posts 
# for the position of AR/VR financial analyst in Menlo Park, CA.
r.extract_keywords_from_text(''.join(raw_data[raw_data["Role"]=="financial analyst"].JD_processed.values))

skills_financial_analyst = r.get_ranked_phrases_with_scores()

# %%
# filter out the less important words from the result
# based on the scores of each words assigned by RAKE NLTK Library
skills_financial_analyst = list(filter(lambda x: int(x[0]) > 2 , skills_financial_analyst))

# %%
skills_financial_analyst[:5]
# Out:
# [(9.0, 'stream process owners'),
#  (9.0, 'reporting provide fp'),
#  (9.0, 'range planning design'),
#  (9.0, 'influencing functional leaders'),
#  (9.0, 'growth tech company')]

# %%
# create string from the list of tuples for drawing wordcloud
text = get_words_as_string(skills_financial_analyst)
# Out:
# stream process owners
# reporting provide fp
# range planning design
# influencing functional leaders
# growth tech company
# financial planning mba
# financial management bachelor
# enhance current tools
# develop actionable insights
# communicating financial concepts
# applicable accounting concepts
# quantitative field 2
# developing analytical frameworks
# support including headcount
# equivalent 2
# efficient headcount
# build frameworks
# analytic support
# systems related
# s degree
# omnichannel direct
# indeed countries
# help center
# completing tasks
# sales leadership
# ms office
# finance economics

# %% [markdown]
# ## EDA
# ***
# Let's draw a wordcloud using the extracted keywords from the JD for a financial analyst role

# %%
draw_word_cloud(text,"financial analyst",[])
